# %% [markdown]
# <a href="https://colab.research.google.com/github/thasniazeez/PROGRAM/blob/main/iris_ann.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/dataset/Iris.csv")
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Species']=le.fit_transform(df['Species'])
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      1            5.1           3.5            1.4           0.2        0
# 1      2            4.9           3.0            1.4           0.2        0
# 2      3            4.7           3.2            1.3           0.2        0
# 3      4            4.6           3.1            1.5           0.2        0
# 4      5            5.0           3.6            1.4           0.2        0
# ..   ...            ...           ...            ...           ...      ...
# 145  146            6.7           3.0            5.2           2.3        2
# 146  147            6.3           2.5            5.0           1.9        2
# 147  148            6.5           3.0            5.2           2.0        2
# 148  149            6.2           3.4            5.4           2.3        2
# 149  150            5.9           3.0            5.1           1.8        2
#
# [150 rows x 6 columns]

# %%
X=df.iloc[:,1:-1]
X
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %%
y=df.iloc[:,-1]
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: Species, Length: 150, dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
scaler.fit(X)
X=scaler.transform(X)
X
# Out:
# array([[0.22222222, 0.625     , 0.06779661, 0.04166667],
#        [0.16666667, 0.41666667, 0.06779661, 0.04166667],
#        [0.11111111, 0.5       , 0.05084746, 0.04166667],
#        [0.08333333, 0.45833333, 0.08474576, 0.04166667],
#        [0.19444444, 0.66666667, 0.06779661, 0.04166667],
#        [0.30555556, 0.79166667, 0.11864407, 0.125     ],
#        [0.08333333, 0.58333333, 0.06779661, 0.08333333],
#        [0.19444444, 0.58333333, 0.08474576, 0.04166667],
#        [0.02777778, 0.375     , 0.06779661, 0.04166667],
#        [0.16666667, 0.45833333, 0.08474576, 0.        ],
#        [0.30555556, 0.70833333, 0.08474576, 0.04166667],
#        [0.13888889, 0.58333333, 0.10169492, 0.04166667],
#        [0.13888889, 0.41666667, 0.06779661, 0.        ],
#        [0.        , 0.41666667, 0.01694915, 0.        ],
#        [0.41666667, 0.83333333, 0.03389831, 0.04166667],
#        [0.38888889, 1.        , 0.08474576, 0.125     ],
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=0)

# %%
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
ann=Sequential()
ann.add(Dense(4,activation='relu'))
ann.add(Dense(10,activation='relu'))
ann.add(Dense(10,activation='relu'))
ann.add(Dense(3,activation='softmax'))

# %%
ann.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
ann.fit(X_train,y_train,batch_size=10,epochs=100)
# Out:
# Epoch 1/100
# 11/11 [==============================] - 3s 4ms/step - loss: 1.1481 - accuracy: 0.5619
# Epoch 2/100
# 11/11 [==============================] - 0s 3ms/step - loss: 1.1285 - accuracy: 0.3905
# Epoch 3/100
# 11/11 [==============================] - 0s 5ms/step - loss: 1.1137 - accuracy: 0.3714
# Epoch 4/100
# 11/11 [==============================] - 0s 6ms/step - loss: 1.0985 - accuracy: 0.3714
# Epoch 5/100
# 11/11 [==============================] - 0s 3ms/step - loss: 1.0809 - accuracy: 0.3714
# Epoch 6/100
# 11/11 [==============================] - 0s 4ms/step - loss: 1.0656 - accuracy: 0.3714
# Epoch 7/100
# 11/11 [==============================] - 0s 4ms/step - loss: 1.0520 - accuracy: 0.5048
# Epoch 8/100
# 11/11 [==============================] - 0s 3ms/step - loss: 1.0391 - accuracy: 0.6381
# Epoch 9/100
# 11/11 [==============================] - 0s 4ms/step - loss: 1.0243 - accuracy: 0.6762
# Epoch 10/100
# ...

# %%
X_train.shape
# Out:
# (105, 4)

# %%
ann.summary()
y_pred=ann.predict(X_test)
y_pred=(y_pred>0.5)
y_pred
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 4)                 20
#
#  dense_1 (Dense)             (None, 10)                50
#
#  dense_2 (Dense)             (None, 10)                110
#
#  dense_3 (Dense)             (None, 3)                 33
#
# ...
# Total params: 213 (852.00 Byte)
# Trainable params: 213 (852.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 2/2 [==============================] - 0s 5ms/step
# array([[False, False,  True],
#        [False,  True, False],
#        [ True, False, False],
#        [False, False,  True],
#        [ True, False, False],
#        [False, False,  True],
#        [ True, False, False],
#        [False,  True, False],
#        [False, False,  True],
#        [False,  True, False],
#        [False, False,  True],
# ...

# %%
y_test
# Out:
# 114    2
# 62     1
# 33     0
# 107    2
# 7      0
# 100    2
# 40     0
# 86     1
# 76     1
# 71     1
# 134    2
# 51     1
# 73     1
# 54     1
# 63     1
# 37     0
# 78     1
# 90     1
# 45     0
# 16     0
# 121    2
# 66     1
# 24     0
# 8      0
# 126    2
# 22     0
# 44     0
# 97     1
# 93     1
# 26     0
# 137    2
# 84     1
# 27     0
# 127    2
# 132    2
# 59     1
# 18     0
# 83     1
# 61     1
# 92     1
# 112    2
# 2      0
# 141    2
# 43     0
# 10     0
# Name: Species, dtype: int64

# %%
loss,accuracy=ann.evaluate(X_test,y_test)
print('Loss',loss)
print('Acccuracy:',accuracy)
# Out:
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2776 - accuracy: 0.9333
# Loss 0.277575820684433
# Acccuracy: 0.9333333373069763

# %%
import pickle
pickle.dump(ann,open('model.sav','wb'))

# %%
model=pickle.load(open('model.sav','rb'))
model

# %%
y_new=ann.predict(scaler.transform([[5.1,3.5,1.4,0.2]]))
# Out:
# 1/1 [==============================] - 0s 31ms/step
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %%
y_new
# Out:
# array([[9.9939382e-01, 2.2652349e-04, 3.7966526e-04]], dtype=float32)

# %%
import numpy as np

# %%
ind=np.argmax(y_new)
print(ind)
pred=le.inverse_transform([ind])
pred
# Out:
# 0
# array(['Iris-setosa'], dtype=object)

# %%
pred.item()
# Out:
# 'Iris-setosa'
